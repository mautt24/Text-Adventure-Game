# %%
"""
Docstring: 

a) Introduction: The game is about my favorite arc of the anime Naruto. 
Knowing the anime will help understand better the game.

    The game consists of three levels divided into stages
    with sub-stages as follows.
    
    1) Defeating 5 "Pain" corpses.
        1.1) Defeating 1 "Pain" corpse.
        1.2) Defeating 4 "Pain" corpse.
    2) Defeating the "Pain" leader.
        2.1) The "Pain" leader attacks.
        2.2) Defeating the "Pain" leader.
    3) Find Nagato, the "Pain" controller.
    

b) Known Bugs: None.
"""

## Importing package
import random

#### Defining the first stage
def stage_1_1():
    
    ## Naming a variable for format purposes
    separator = ('*'*50)

    ## Setting the title and printing it
    title = """The story of Naruto Uzumaki - Naruto vs. "Pain" arc"""
    print(title)

    ## Context of the text adventure game and instructions
    print(f"""
    {separator}

    -Naruto went to learn "senjutsu" with the sage toads in Mount 
    Myoboku as he is looking to avenge his sensei Jiraiya. 

    In the meantime, the city of Konoha is being attacked by "Pain", a 
    group of 6 corpses controlled by Nagato, Jiraiya's killer. They 
    completely razed Konoha defeating all their powerful "shinobis" 
    including Kakashi and the fifth Hokage Tsunade. 

    Naruto is summoned to Konoha by one of the sage toads, that was in 
    Konoha, just on time after dominating "senjutsu". He can't believe 
    what has happened to Konoha in his absence... 
    Suddenly... The "Pain" leader appears a few meters in front of him.

    One of the sage toads tells Naruto that "Pain" is low in chakra as he
    used most of it against Konoha, so it would be a good moment to fight him
    before he gets it back.-

    {separator} 

    -You are now to guide Naruto. Choose the best actions to defeat "Pain".-

    {separator}
    """)

    ## Beginning of the first loop
    while True:
        
        ## Asking for input
        first_action = input(prompt = f"""
    What should Naruto do?  Choose: 
    1) Attack
    2) Escape \n

    {separator}
    """)

        first_action = first_action.casefold() ## Lowercasing every character
        
        ## Considering possible inputs for option 1
        if first_action == '1' or 'at' in first_action:
            print(f"""
    {separator}
    RASENGAN!!!
    {separator}       
    """)
            stage_1_2() ## Going to that stage
            break

        ## Considering possible inputs for option 2
        elif first_action == "2" or 'e' in first_action:
            print(f"""
    {separator}
    Naruto never escapes.       
    {separator}
    """)
            fail() ## Going to that function
            break

        ## Considering every other possible input
        else:
            print(f"""
    Please answer Attack or Escape.

    {separator}
    """)
            continue
    ## End of the first loop

### Defining stage 1.2    
def stage_1_2():
    
    ## Naming a variable for format purposes
    separator = ('*'*50)

    ## Storytelling continuing
    print(f"""
    -Naruto targets the "Pain" leader but one of the other 5 jumps in front
    to protect him and gets demolished by the Rasengan. 

    "Pain" leader recognizes Naruto's strength and tells him that he is only
    looking for peace and that he was also Jiraiya's 
    student. 

    Naruto can't believe what he's hearing... How could his student kill
    his sensei!!? He immediately gets filled with rage.-

    {separator}
    """)

    print(f"""
    -Naruto must destroy the other 4 "Pain" corpses before the "Pain" leader 
    comes up with a strategy against Naruto.-

    {separator}
    """)

    ## Beginning of the second loop  
    while True:
        
        ## Asking for input
        second_action = input(prompt = f"""
    Which move should Naruto do next?  Choose: 
    1) Odama Rasengan
    2) Rasenshuriken
    3) Kagebunshin 
    4) Scream for help! 
    5) Surrender \n

    {separator}
    """)

        second_action = second_action.casefold() ## Lowercasing every character
        
        ## Considering every other possible input
        if second_action == "1" or "odama rasengan" in second_action or "od" in second_action:
            print(f"""
    -Naruto in a blink strikes with a super big "Odama Rasengan" exploding 
    into pieces 4 "Pains".-

    {separator}
    """)
            stage_2_1() ## Going to that stage
            break

        ## Considering possible inputs for option 2
        elif second_action == "2" or "rasenshuriken" in second_action or "rasens" in second_action:
            print(f"""
    -Naruto in a blink strikes with a super powerful "Rasenshuriken" with 
    such a big area of range impact that it sends into oblivion 4 
    "Pain" corpses.-

    {separator}
    """)
            stage_2_1() ## Going to that stage
            break

        ## Considering possible inputs for option 3
        elif second_action == "3" or "kagebunshin" in second_action or "kage" in second_action:
            print(f"""
    -Naruto clones himself 1,000 times with the "Kagebunshin No Jutsu"
    and with "taijutsu" skills they manage to end 3 "Pains".-

    {separator}
    """)
            
            ## Asking for input
            KB_quick_decision = input(prompt = """
        -Naruto must end with at least 4 "Pains" before "Pain" leader gets back his 
        chakra, otherwise it will be impossible to defeat him.-

        Choose a "jutsu":
        1) Rasengan
        2) Oiroke No Jutsu
        """)
            
            KB_quick_decision = KB_quick_decision.casefold() ## Lowercasing every character

            ## Beginning of nested conditional        
            ## Considering possible inputs for option 3.1
            if KB_quick_decision == '1' or "rasengan" in KB_quick_decision or "ra" in KB_quick_decision:
                print(f"""
        {separator}

        RASENGAN!!!
        {separator}
        Naruto hits the fifth Pain with a powerful Rasengan and destroys him.        
        {separator}       
        """)
                stage_2_1() ## Going to that stage
                break

            ## Considering possible inputs for option 3.2
            elif KB_quick_decision == '2' or "oiroke no jutsu" in KB_quick_decision or 'o' in KB_quick_decision:
                print(f"""
        Oiroke No Jutsu!
        {separator}
        Naruto transforms himself into a supermodel which distracts the fifth
        "Pain" and hits him so hard that he destroys him.
        {separator}
        """)
                stage_2_1() ## Going to that stage
                break

            ## Considering every other possible input
            else:
                print(f"""
    Please choose one jutsu. 
    {separator}
    """)
                continue
        ## Ending of nested conditional

        ## Considering possible inputs for option 4
        elif second_action == "4" or "scream for help!" in second_action or "help" in second_action or "scream" in second_action:
            print(f"""
    -Even though it is always good to ask friends for help, Naruto
    never get scared if the opponent is stronger.
    Besides, there is no one else that can help Naruto right now.-

    {separator}

    -"Pain" leader takes advantage of Naruto's panic and lands a big punch on him...-

    {separator}
    """)
            
            ## Asking for input
            quick_decision = input(prompt = f"""
        Decide what must Naruto do:

        1) Escape
        2) Fight

        {separator}
        """)
            
            quick_decision = quick_decision.casefold() ## Lowercasing every character

            ## Beginning of nested conditional
            ## Considering possible inputs for option 4.1
            if quick_decision == "1" or "escape" in quick_decision or "e" in quick_decision:
                print(f"""
        {separator}
        Naruto never escapes.
        {separator}
        """)
                fail() ## Going to that function
                break

            ## Considering possible inputs for option 4.2
            elif quick_decision == "2" or "fight" in quick_decision or "f" in quick_decision:
                print(f"""
        -Naruto gets back on his feet and lands a super punch to one of the "Pains", throwing him
        100 meters away, and leaving him out of play.-
        
        -He then creates "Kage Bunshin" clones and throws a "Rasenshuriken" to the other
        3 secondary "Pains" leaving just the Pain leader for the main plate.-

        {separator}
        """)
                stage_2_1() ## Going to that stage
                break

            ## Considering every other possible input
            else:
                print(f"""
        Please choose "Escape" or "Fight".

        {separator}
        """)
                continue
        ## Ending of nested conditional

        ## Considering possible inputs for option 5
        elif second_action == "5" or "surrender" in second_action or "su" in second_action:
            print(f""" 
    You have surrendered!
    {separator}
    """)
            fail() ## Going to that function
            break

        ## Considering every other possible input
        else:
            print(f"""
    Please choose one of the 5 actions.
    
    {separator}
    """)
            continue
            ## End of the second loop
    
#### Defining the second stage
def stage_2_1():
    
    ## Naming a variable for format purposes
    separator = ('*'*50)

    print(f"""
    -The "Pain" leader is gaining back his chakra, Naruto must end this 
    before it's too late.-

    {separator}

    -"Pain" leader quickly makes a seal with his hand. Naruto doesn't have time to react
    and "Pain" attacks him with a "jutsu".-

    {separator}
    """)
    
    ## Creating a list of Pain leader "jutsus"
    Pain_jutsus_list = ["Chibaku Tensei", "Kuchiyose no Jutsu", "King of Hell", "Shinra Tensei", "Bansho Tenin"]

    ## Beginning of the third loop
    while True:

        Pain_jutsu = random.choice(Pain_jutsus_list) ## Obtaining a random element from the list and saving it to a new variable
        
        ## Asking for input
        input(prompt = """
    Press enter button to see which "jutsu" Pain leader chose. \n
    """)
        
        if Pain_jutsu == "Chibaku Tensei":
            print(f"""
    Chibaku Tensei!!! = Planetary devastation

    -"Pain" covers Naruto in big rocks creating a moon.-

    -Naruto has two options: die or keep fighting-

    -To keep fighting he must let Kurama's 
    (the nine-tailed demon fox sealed inside him) 
    chakra take over Naruto's body, as "Pain" is stronger 
    than Naruto.

    -The problem is that if Naruto resorts to this, Kurama might 
    free himself, killing Naruto and attacking Konoha.-

    Choose wisely!!!

    {separator}
    """)
            
            ## Asking for input
            important_decision = input(prompt = f"""
        Choose:
        1) Die
        2) Keep fighting

        {separator}
        """)
            
            important_decision = important_decision.casefold() ## Lowercasing every character
            
            ## Beginning of nested conditional
            ## Considering possible inputs for option 1
            if important_decision == "1" or "die" in important_decision or "d" in important_decision:
                print(f"""
        -Naruto gave up... Naruto must never give up...
        He can't stop until he becomes the Hokage.-
        {separator}
        """)
                fail() ## Going to that function
                break

            ## Considering possible inputs for option 2
            elif important_decision == "2" or "keep fighting" in important_decision or "k" in important_decision:
                print(f"""
        -Naruto plunges into a rage and Kurama's chakra takes over
        Naruto's body.- 

        -"Kurama Chakra Mode Naruto" immediately explodes the moon.-

        -Minato's (Naruto's father) spirit appears to control the 
        seal of Kurama in Naruto, preventing the demon fox from escaping. 
        Naruto gains control back.-

        {separator}
        """)
                stage_2_2() ## Going to that stage
                break

            ## Considering every other possible input
            else:
                print(f"""
        Please choose "Die" or "Keep fighting".   

        {separator}
        """)
                continue
        ## Ending of nested conditional

        elif Pain_jutsu == "Kuchiyose no Jutsu":
            print(f"""
    Kuchiyose no Jutsu!!! = Summoning Jutsu

    -"Pain" summons 4 big monsters but they are nothing compared to Naruto's
    current strength so he defeats them in matter of seconds.-

    {separator}
    """)
            stage_2_2() ## Going to that stage
            break
            
        elif Pain_jutsu == "King of Hell":
            print(f"""
    King of Hell!!!

    -The King of Hell sucks out Naruto's soul...-

    -There is nothing left to do.-
    {separator}
    """)
            fail() ## Going to that function
            break

        elif Pain_jutsu == "Shinra Tensei":
            print(f"""
    Shinra Tensei!!! = All-Mighty Push

    -"Pain" applies "Shinra Tensei" to Naruto throwing him 1 km away while
    destroying everything in that radius.- 

    -Naruto received a big impact but he can keep going.-

    {separator}
    """)
            stage_2_2() ## Going to that stage
            break

        elif Pain_jutsu == "Bansho Tenin":
            print(f"""
    Bansho Tenin!!! = All-Mighty Pull

    -"Pain" applies "Bansho Tenin" to Naruto pulling him like he was 
    a super-powerful magnet and then Naruto receives a big hit.- 

    -Naruto received a big impact but he can keep going.-

    {separator}
    """)
            stage_2_2() ## Going to that stage
            break

        ## Asking to input something to proceed with the game
        else:
            print(f"""
    Please type enter to continue

    {separator}
    """)
            continue
            ## End of the third loop
            
### Defining stage_2.2
def stage_2_2():
    
    ## Naming a variable for format purposes
    separator = ('*'*50)
    
    ## Beginning of the fourth loop 
    while True:

        ## Asking for input
        Naruto_finishes_Pain = input(prompt = f"""
    -After razing Konoha and using a lot of chakra for the big "jutsus" against 
    Naruto, the "Pain" leader looks tired and is left with no chakra whatsoever.-

    -Naruto is still standing with enough chakra.-

    Finish "Pain"!
    {separator}

    Choose the final "jutsu":
    1) Senpou Cho Odama Rasengan
    2) Odama Rasen Shuriken

    {separator}
    """)
        
        Naruto_finishes_Pain = Naruto_finishes_Pain.casefold() ## Lowercasing every character
        
        ## Considering possible inputs for option 1
        if Naruto_finishes_Pain == '1' or "senp" in Naruto_finishes_Pain or "raseng" in Naruto_finishes_Pain:
            print(f"""
    Senpou Cho Odama Rasengan!!!

    -Naruto hits "Pain" leader all the way and is finally destroyed.-
    {separator}
    """)
            stage_3() ## Going to that stage
            break

        ## Considering possible inputs for option 2
        elif Naruto_finishes_Pain == '2' or "odama rasen shuriken" in Naruto_finishes_Pain or "shuriken" in Naruto_finishes_Pain:
            print(f"""
    Odama Rasen Shuriken!!!

    -Naruto hits "Pain" leader directly with his strongest "jutsu" completely
    destroying him.-
    {separator}
    """)
            stage_3() ## Going to that stage
            break

        ## Considering every other possible input
        else:
            print(f"""
    Please choose one final attack.    
    {separator}
    """) 
            continue
            ## End of the fourth loop
        
#### Defining the third and final stage
def stage_3():
    
    ## Naming a variable for format purposes
    separator = ('*'*50)

    ## Beginning of the fifth loop 
    while True:

        ## Asking for input
        End_of_Nagato = input(prompt = f"""
    -After beating "Pain", Naruto senses Nagato's chakra a few km 
    away and goes to get him.-

    -Naruto finds Nagato who is in a very bad condition unable to move as
    he doesn't have any more chakra for controlling all the "Pains" during their 
    fight.-

    Naruto must make a decision... 

    1) End Nagato
    2) Talk with Nagato

    Choose wisely!
    {separator}
    """)
        
        End_of_Nagato = End_of_Nagato.casefold() ## Lowercasing every character
        
        ## Considering possible inputs for option 1
        if End_of_Nagato == "1" or "e" in End_of_Nagato:
            print(f"""
    -Naruto finishes Nagato, avenging all his down friends. 
    Nevertheless, he feels so empty, that nothing matters 
    to him anymore, so he gives up on his dream of becoming Hokage.

    -Naruto lost his ninja way.-
    {separator}
    """) 
            fail() ## Going to that function
            break

        ## Considering possible inputs for option 2
        elif End_of_Nagato == '2' or "ta" in End_of_Nagato:
            print(f"""
    -After a long conversation with Nagato, Naruto convinces him that
    what he did is not the way to achieve peace.
    Nagato feels sorry for his acts and decides to resurrect all the
    people from Konoha that he killed.-

    -Naruto, really proud of what he achieved, comes back to Konoha where
    all the people were waiting to congratulate him as never before.-

    -Naruto finally was recognized by everyone and became the hero of Konoha!-
    """) 
            win() ## Going to that function
            break

        ## Considering every other possible input
        else:
            print(f"""
    Please choose one decision.
    {separator}
    """)
            continue
            ## End of fifth loop

### Defining fail
def fail():
    
    ## Naming a variable for format purposes
    separator = ('*'*50)
    
    print(f"""
GAME OVER
{separator}
""")
    
    ## Beginning of the sixth loop 
    while True:

        ## Asking for input
        play_again_fail = input(prompt = f"""
Want to play again?
Type 1 for yes or 2 for no.
{separator}
""")

        ## Trying for errors in input
        try: 
            
            ## Changing the type of the input from string to integer
            play_again_fail = int(play_again_fail)
            
            ## Considering possible input
            if play_again_fail == 1:
                print(f"""
Great!
{separator}
""")
                stage_1_1() ## Going to that stage
                break
            
            ## Considering possible input
            elif play_again_fail == 2:
                print(f"""
Bye!
{separator}
""")
                break ## Ending game

        ## Telling the player what to input
        except:
            print(f"""
Choose 1 or 2.
{separator}
""")
    ## End of sixth loop

### Defining win    
def win():
    
    ## Naming a variable for format purposes
    separator = ('*'*50)
    
    print(f"""
YOU HAVE WON THE GAME!!!
CONGRATULATIONS!!!
{separator}    
""")
    
    ## Beginning of the seventh loop 
    while True:

        ## Asking for input
        play_again_win = input(prompt = f"""
Want to play again?
Type 1 for yes or 2 for no.
{separator}
""")
        
        ## Trying for errors in input
        try: 
            
            ## Changing the type of the input from string to integer
            play_again_win = int(play_again_win)

            ## Considering possible input
            if play_again_win == 1:
                print(f"""
Great!
{separator}
""")
                stage_1_1() ## Going to that stage
                break

            ## Considering possible input
            elif play_again_win == 2:
                print(f"""
Bye!
{separator}
""")
                break ## Ending game


        ## Telling the player what to input
        except:
            print("""
Choose 1 or 2.
""")
    ## End of seventh loop

## Returning first defined function            
stage_1_1()
# Out:
# The story of Naruto Uzumaki - Naruto vs. "Pain" arc
#
#     **************************************************
#
#     -Naruto went to learn "senjutsu" with the sage toads in Mount
#     Myoboku as he is looking to avenge his sensei Jiraiya.
#
#     In the meantime, the city of Konoha is being attacked by "Pain", a
#     group of 6 corpses controlled by Nagato, Jiraiya's killer. They
#     completely razed Konoha defeating all their powerful "shinobis"
#     including Kakashi and the fifth Hokage Tsunade.
#
#     Naruto is summoned to Konoha by one of the sage toads, that was in
#     Konoha, just on time after dominating "senjutsu". He can't believe
#     what has happened to Konoha in his absence...
#     Suddenly... The "Pain" leader appears a few meters in front of him.
#
#     One of the sage toads tells Naruto that "Pain" is low in chakra as he
#     used most of it against Konoha, so it would be a good moment to fight him
#     before he gets it back.-
#
# ...
